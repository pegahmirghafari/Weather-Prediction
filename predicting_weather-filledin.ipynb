# %% [markdown]
# Predicting the Weather with Neural Networks
# ===========================================

# %% [markdown]
# Example neural network

# %% [markdown]
# ![title](img/ANN_with_numbers.png)

# %% [markdown]
# Import libraries

# %%
from google.colab import drive
drive.mount("/content1")
# Out:
# Mounted at /content1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Read a CSV data file.

# %%
df = pd.read_csv("/content1/MyDrive/Colab Notebooks/weather prediction /weatherPerth.csv")
df.head()
# Out:
#          Date Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  2008-07-01    Perth      2.7  ...         No      0.0            No
# 1  2008-07-02    Perth      6.4  ...         No      0.4            No
# 2  2008-07-03    Perth      6.5  ...         No      1.8           Yes
# 3  2008-07-04    Perth      9.5  ...        Yes      1.8           Yes
# 4  2008-07-05    Perth      9.5  ...        Yes      6.8           Yes
#
# [5 rows x 24 columns]

# %% [markdown]
# Pre-process the data.  First, remove unwanted variables.

# %%
exclude = ['Date', 'RISK_MM', 'Location']
for var in exclude:
    del df[var]

# %% [markdown]
# Dealing with missing values.

# %%
df = df.dropna()

# %% [markdown]
# Boolean variables to 0s and 1s.

# %%
bools = ['RainToday', 'RainTomorrow']
for var in bools:
    df[var] = df[var].map({
        'Yes': 1,
        'No': 0
    })
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  ...  Temp3pm  RainToday RainTomorrow
# 1      6.4     20.7       0.0  ...     19.7          0            0
# 3      9.5     19.2       1.8  ...     17.7          1            1
# 4      9.5     16.4       1.8  ...     16.0          1            1
# 5      0.7     15.9       6.8  ...     15.5          1            0
# 6      0.7     18.3       0.0  ...     17.9          0            0
#
# [5 rows x 21 columns]

# %% [markdown]
# Cyclical attributes

# %%
wind_attributes = ['WindGustDir', 'WindDir9am', 'WindDir3pm']

# Cardinal direction to radians
dirs = ['N','NNE','NE','ENE','E','ESE','SE','SSE','S','SSW','SW','WSW','W','WNW','NW','NNW']
angles = np.arange(0.0, 2.0*np.pi, 2.0*np.pi / 16.0)
wind_angles = dict(zip(dirs, angles))
print(wind_angles)

for var in wind_attributes:
    df[var] = df[var].map(wind_angles)
    df[var + '_cos'] = np.cos(df[var])
    df[var + '_sin'] = np.sin(df[var])
    df = df.drop(columns=var)
df.head()
# Out:
# {'N': 0.0, 'NNE': 0.39269908169872414, 'NE': 0.7853981633974483, 'ENE': 1.1780972450961724, 'E': 1.5707963267948966, 'ESE': 1.9634954084936207, 'SE': 2.356194490192345, 'SSE': 2.748893571891069, 'S': 3.141592653589793, 'SSW': 3.5342917352885173, 'SW': 3.9269908169872414, 'WSW': 4.319689898685965, 'W': 4.71238898038469, 'WNW': 5.105088062083414, 'NW': 5.497787143782138, 'NNW': 5.890486225480862}
#    MinTemp  MaxTemp  Rainfall  ...  WindDir9am_sin  WindDir3pm_cos  WindDir3pm_sin
# 1      6.4     20.7       0.0  ...        0.923880        0.382683        0.923880
# 3      9.5     19.2       1.8  ...        0.382683        0.923880       -0.382683
# 4      9.5     16.4       1.8  ...       -1.000000       -0.707107       -0.707107
# 5      0.7     15.9       6.8  ...        0.923880        0.707107        0.707107
# 6      0.7     18.3       0.0  ...        0.707107        0.923880        0.382683
#
# [5 rows x 24 columns]

# %% [markdown]
# Extract attributes (X) and class labels (y).

# %%
y = df["RainTomorrow"]
X = df.drop(columns="RainTomorrow")

# %% [markdown]
# Split dataset into training and testing subsets.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.33,
    random_state=0
)

# %%
print('X_train', X_train.shape)
print('X_test', X_test.shape)
print('y_train', y_train.shape)
print('y_test', y_test.shape)
# Out:
# X_train (2026, 23)
# X_test (999, 23)
# y_train (2026,)
# y_test (999,)

# %% [markdown]
# Scale.

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Instantiate a neural network and train it.

# %% [markdown]
# Input layer size.

# %%
print(X_train.shape)
# Out:
# (2026, 23)

# %%
classifier = MLPClassifier(
    hidden_layer_sizes=(50,50),
    max_iter=500,
    random_state=0
)
classifier.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=500, random_state=0)

# %% [markdown]
# Predict target class for the testing set.

# %%
y_pred = classifier.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8928928928928929

# %% [markdown]
# Search for best network layout.

# %%
parameters = {
    'hidden_layer_sizes': ((2,), (5,) ,(10,), (50,50)),
    'max_iter': ((100),(300),(400),(500),(1000),(1500),(2000))
}
nn = MLPClassifier(max_iter=2000, random_state=0)
gridsearch = GridSearchCV(nn, parameters, cv=3)
gridsearch.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# GridSearchCV(cv=3, estimator=MLPClassifier(max_iter=2000, random_state=0),
#              param_grid={'hidden_layer_sizes': ((2,), (5,), (10,), (50, 50)),
#                          'max_iter': (100, 300, 400, 500, 1000, 1500, 2000)})

# %% [markdown]
# Display grid search results.

# %%
print(gridsearch.cv_results_['params'])
print(gridsearch.cv_results_['mean_test_score'])
# Out:
# [{'hidden_layer_sizes': (2,), 'max_iter': 100}, {'hidden_layer_sizes': (2,), 'max_iter': 300}, {'hidden_layer_sizes': (2,), 'max_iter': 400}, {'hidden_layer_sizes': (2,), 'max_iter': 500}, {'hidden_layer_sizes': (2,), 'max_iter': 1000}, {'hidden_layer_sizes': (2,), 'max_iter': 1500}, {'hidden_layer_sizes': (2,), 'max_iter': 2000}, {'hidden_layer_sizes': (5,), 'max_iter': 100}, {'hidden_layer_sizes': (5,), 'max_iter': 300}, {'hidden_layer_sizes': (5,), 'max_iter': 400}, {'hidden_layer_sizes': (5,), 'max_iter': 500}, {'hidden_layer_sizes': (5,), 'max_iter': 1000}, {'hidden_layer_sizes': (5,), 'max_iter': 1500}, {'hidden_layer_sizes': (5,), 'max_iter': 2000}, {'hidden_layer_sizes': (10,), 'max_iter': 100}, {'hidden_layer_sizes': (10,), 'max_iter': 300}, {'hidden_layer_sizes': (10,), 'max_iter': 400}, {'hidden_layer_sizes': (10,), 'max_iter': 500}, {'hidden_layer_sizes': (10,), 'max_iter': 1000}, {'hidden_layer_sizes': (10,), 'max_iter': 1500}, {'hidden_layer_sizes': (10,), 'max_iter': 2000}, {'hidden_layer_sizes': (50, 50), 'max_iter': 100}, {'hidden_layer_sizes': (50, 50), 'max_iter': 300}, {'hidden_layer_sizes': (50, 50), 'max_iter': 400}, {'hidden_layer_sizes': (50, 50), 'max_iter': 500}, {'hidden_layer_sizes': (50, 50), 'max_iter': 1000}, {'hidden_layer_sizes': (50, 50), 'max_iter': 1500}, {'hidden_layer_sizes': (50, 50), 'max_iter': 2000}]
# [0.79812477 0.89634889 0.90227117 0.90473884 0.90424355 0.90424355
#  0.90424355 0.89782818 0.90523267 0.90473738 0.90424355 0.90621886
#  0.90621886 0.90621886 0.90670977 0.90671342 0.90424428 0.90029732
#  0.8968471  0.89487179 0.89487179 0.90227263 0.88895098 0.88450873
#  0.88450873 0.88450873 0.88450873 0.88450873]

# %% [markdown]
# Predictions using the best neural network.

# %%
best_nn = gridsearch.best_estimator_
y_pred = best_nn.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9079079079079079
